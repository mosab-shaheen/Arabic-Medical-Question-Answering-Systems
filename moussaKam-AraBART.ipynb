# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, TensorDataset
from datasets import Dataset
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Trainer, TrainingArguments
import pickle
import gc


# Load the MAQA dataset
data = pd.read_csv(r'D:\Jupyter Notebook\Research\Datasets\Medical\MAQA\MAQA_length30.csv', encoding='utf-16', sep='\t')
#data_svm = pd.read_csv(r'C:\Users\mosab\Desktop\Datasets\Medical\MAQA\MAQA_length30_SVM.csv', encoding='utf-16', sep='\t')

# # Preprocess dataset
# def preprocess_data(df):
#     df = df.dropna()  # Drop missing data
#     return df

# data = preprocess_data(data)

# %%
# Split the dataset into train (70%), validation (20%), and test (10%) while keeping category proportions
train_df, temp_df = train_test_split(data, test_size=0.3, stratify=data['category'], random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.33, stratify=temp_df['category'], random_state=42)

# Split the dataset into train (70%), validation (20%), and test (10%) while keeping category proportions
#train_df_svm, temp_df_svm = train_test_split(data_svm, test_size=0.3, stratify=data_svm['category'], random_state=42)
#val_df_svm, test_df_svm = train_test_split(temp_df_svm, test_size=0.33, stratify=temp_df_svm['category'], random_state=42)

# %%
train_df.head()
# Out:
#                                                  question  \
# 227320  هل اشعه الراوتر الذي يستخدم في بث الانترنت مضر...
# 4095           اسباب الحرقه البسيطه عند التبول عند الرجال
# 74486   السلام عليكم طهور فطريات في اللثه واختفت خلال ...
# 100878  ظهرت لدي حبوب وتقرحات تحرق الجلد في منطقه البط...
# 67677   انا فتاه في الثامنه عشر من العمر لدي الم في اس...
#
#                                                    answer  \
# 227320  لا يوجد الي الان اي دليل علمي يفيد بان الاشعه ...
# 4095                                البروتينات استخداماته
# 74486       هذه اعراض عامه راجع اختصاصي امرض الاسنان اولا
# 100878  يجب اخذ السيره المرضيه وفحص المنطقه لامكانيه ا...
# 67677                                          افحص سونار
#
#                                 category
# 227320                        الطب العام
# 4095    امراض المسالك البولية والتناسلية
# 74486                    الامراض الجنسية
# 100878                   الامراض الجلدية
# 67677                       امراض نسائية

# %%
#train_df_svm.head()

# %%
val_df.head()
# Out:
#                                                 question  \
# 74538  السلام عليكم شكرا لكم علي جهدكم السؤال هل عاده...
# 25887  اشعر بالم خلف الركبه نتيجه التواء اثناء لعب كر...
# 35343  اعاني من الم بالفك الايمن تنمل في الاذن احيانا...
# 60966  انا اعاني من الم شديد في اسفل كعب الرجل اليمني...
# 20423  اعاني من ذياده صبغه في الجلد مخلي جلدي اسود في...
#
#                                                   answer  \
# 74538  التفكير في الجنس لا يضر بالجهاز التناسلي بل هو...
# 25887                                        تمت الاجابه
# 35343  قد يكون مشكل في الاسنان او في مفصل الفك الايمن...
# 60966  قد يكون السبب وجود منقار عظمي في الكعب ينصح عم...
# 20423  علاج اللون الاسمر علي الجلد فيستغرق وقتا طويلا...
#
#                               category
# 74538                  الامراض الجنسية
# 25887  امراض العضلات والعظام و المفاصل
# 35343                   انف اذن وحنجرة
# 60966  امراض العضلات والعظام و المفاصل
# 20423                  الامراض الجلدية

# %%
#val_df_svm.head()

# %%
# # Define a TF-IDF vectorizer for SVM category classification
# vectorizer = TfidfVectorizer(max_features=5000)
# X_train = vectorizer.fit_transform(train_df_svm['question']).toarray()  # Convert to dense array
# X_val = vectorizer.transform(val_df_svm['question']).toarray()  # Convert to dense array
# X_test = vectorizer.transform(test_df_svm['question']).toarray()  # Convert to dense array

# %%
#X_train.shape

# %%
# # Encode the target labels (categories)
# label_encoder = LabelEncoder()
# y_train = label_encoder.fit_transform(train_df_svm['category'])
# y_val = label_encoder.transform(val_df_svm['category'])
# y_test = label_encoder.transform(test_df_svm['category'])

# # Convert data to PyTorch tensors
# X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
# y_train_tensor = torch.tensor(y_train, dtype=torch.long)  # Use long for CrossEntropyLoss

# X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
# #y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
# #y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# %%
# # Define the Multiclass SVM model using PyTorch
# class MultiClassSVM(nn.Module):
#     def __init__(self, input_dim, num_classes):
#         super(MultiClassSVM, self).__init__()
#         self.fc = nn.Linear(input_dim, num_classes)  # Multiclass classification

#     def forward(self, x):
#         return self.fc(x)

# %%
# # Create data loaders
# train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
# #val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
# #test_dataset = TensorDataset(X_test_tensor, y_test_tensor)


# train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
# #val_loader = DataLoader(val_dataset, batch_size=64)
# #test_loader = DataLoader(test_dataset, batch_size=64)


# # Initialize the model
# input_dim = X_train.shape[1]  # Number of features from TF-IDF
# num_classes = len(label_encoder.classes_)  # 20 categories for the questions
# SVM_model = MultiClassSVM(input_dim, num_classes)

# # Define the loss function (CrossEntropyLoss for multiclass classification)
# criterion = nn.CrossEntropyLoss()

# # Define the optimizer
# optimizer = optim.Adam(SVM_model.parameters(), lr=0.001)

# # Training loop
# def train_multiclass_svm(SVM_model, train_loader, optimizer, criterion, num_epochs=10):
#     SVM_model.train()
#     for epoch in range(num_epochs):
#         epoch_loss = 0
#         for inputs, targets in train_loader:
#             optimizer.zero_grad()
#             outputs = SVM_model(inputs)
#             loss = criterion(outputs, targets)  # Use CrossEntropyLoss
#             loss.backward()
#             optimizer.step()
#             epoch_loss += loss.item()
#         print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss/len(train_loader)}")

# # Train the multiclass SVM model
# train_multiclass_svm(SVM_model, train_loader, optimizer, criterion, num_epochs=10)

# %%
# # Save the trained SVM model to disk
# with open("C:/Users/mosab/Desktop/Jupyter Notebook/Research/models/svm_classifier.pkl", 'wb') as f:
#     pickle.dump(SVM_model, f)

# %%
# # Reload SVM classifier from saved file (after clearing GPU memory)
# with open("C:/Users/mosab/Desktop/Jupyter Notebook/Research/models/svm_classifier.pkl", 'rb') as f:
#     SVM_model = pickle.load(f)

# %%
# # Predict categories for validation set
# def predict(SVM_model, X):
#     SVM_model.eval()
#     with torch.no_grad():
#         outputs = SVM_model(X)
#         _, predicted = torch.max(outputs, 1)  # Get the index of the max log-probability
#         return predicted

# # Predict on validation data
# y_val_pred = predict(SVM_model, X_val_tensor)
# y_test_pred = predict(SVM_model, X_test_tensor)

# # Convert predicted numerical categories back to string labels
# val_df['predicted_category'] = label_encoder.inverse_transform(y_val_pred.cpu().numpy())  # Convert to category names
# test_df['predicted_category'] = label_encoder.inverse_transform(y_test_pred.cpu().numpy())  # Convert to category names


# # Clear GPU memory
# print("Clearing GPU memory...")
# gc.collect()
# torch.cuda.empty_cache()

# %%
# # Report SVM classification accuracy
# print("SVM Validation Results")
# print(classification_report(val_df['category'], val_df['predicted_category']))

# print("SVM Test Results")
# print(classification_report(test_df['category'], test_df['predicted_category']))

# %%
max_length_input = 139  # For questions   #190
max_length_output = 230  # For answers

# Prepare datasets for fine-tuning the AraT5 model
def preprocess_function_train(examples):
    input_texts = []
    target_texts = []
    for question, answer, category in zip(examples['question'], examples['answer'], examples['category']):
        input_texts.append(f"category: {category} question: {question}")
        target_texts.append(answer)
    model_inputs = tokenizer(input_texts, max_length=max_length_input, truncation=True, padding="max_length")
    labels = tokenizer(target_texts, max_length=max_length_output, truncation=True, padding="max_length").input_ids
    model_inputs["labels"] = labels
    return model_inputs

# Prepare datasets for fine-tuning the AraT5 model
def preprocess_function_test(examples):
    input_texts = []
    #target_texts = []
    for question, category in zip(examples['question'], examples['category']): #examples['predicted_category']
        input_texts.append(f"category: {category} question: {question}")
        #target_texts.append(answer)
    model_inputs = tokenizer(input_texts, max_length=max_length_input, truncation=True, padding="max_length")
    #labels = tokenizer(target_texts, max_length=max_length_output, truncation=True, padding="max_length").input_ids
    #model_inputs["labels"] = labels
    return model_inputs

# %%
# !set PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
# Load AraT5 tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("moussaKam/AraBART")
model = AutoModelForSeq2SeqLM.from_pretrained("moussaKam/AraBART")

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


train_dataset = Dataset.from_pandas(train_df).map(preprocess_function_train, batched=True)
val_dataset = Dataset.from_pandas(val_df).map(preprocess_function_train, batched=True)

# Fine-tune the model
training_args = TrainingArguments(
    output_dir='./results/moussaKam/AraBART',
    learning_rate=5e-5,
    per_device_train_batch_size=6,
    per_device_eval_batch_size=6,
    gradient_accumulation_steps=8,  # Accumulate gradients over 8 batches
    fp16=True,  # Enable mixed precision training to reduce GPU memory requirement
    num_train_epochs=3,
    weight_decay=0.01,
    save_total_limit=3,
    load_best_model_at_end=True,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="steps",
    eval_steps=250,
    save_steps=250,
    save_strategy="steps",
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    tokenizer=tokenizer
)
# Out:
# C:\Users\mosab\anaconda3\envs\tf\lib\site-packages\huggingface_hub\file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map: 100%|██████████| 178160/178160 [00:51<00:00, 3445.90 examples/s]
# Map: 100%|██████████| 51157/51157 [00:14<00:00, 3464.50 examples/s]
# C:\Users\mosab\anaconda3\envs\tf\lib\site-packages\transformers\training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
from datetime import datetime
now = datetime.now()
print(now.time())
# Out:
# 22:46:28.066347

# %%
#trainer.train(resume_from_checkpoint=True)
trainer.train()

# Save the fine-tuned model
tokenizer.save_pretrained("D:/Jupyter Notebook/Research/models/moussaKam-AraBART")
model.save_pretrained("D:/Jupyter Notebook/Research/models/moussaKam-AraBART")
# Out:
#     <div>
#
#       <progress value='251' max='11133' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  251/11133 07:23 < 5:23:02, 0.56 it/s, Epoch 0.07/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='3566' max='8527' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3566/8527 04:25 < 06:09, 13.43 it/s]
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\tf\lib\site-packages\accelerate\utils\operations.py:155, in send_to_device(tensor, device, non_blocking, skip_keys)
#     154 try:
# --> 155     return tensor.to(device, non_blocking=non_blocking)
#     156 except TypeError:  # .to() doesn't accept non_blocking as kwarg
#
# TypeError: to() got an unexpected keyword argument 'non_blocking'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 #trainer.train(resume_from_checkpoint=True)
# ----> 2 trainer.train()
#       4 # Save the fine-tuned model
#       5 tokenizer.save_pretrained("C:/Users/mosab/Desktop/Jupyter Notebook/Research/models/moussaKam-AraBART")
#
# File ~\anaconda3\envs\tf\lib\site-packages\transformers\trainer.py:1885, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1883         hf_hub_utils.enable_progress_bars()
#    1884 else:
# -> 1885     return inner_training_loop(
#    1886         args=args,
#    1887         resume_from_checkpoint=resume_from_checkpoint,
#    1888         trial=trial,
#    1889         ignore_keys_for_eval=ignore_keys_for_eval,
#    1890     )
#
# File ~\anaconda3\envs\tf\lib\site-packages\transformers\trainer.py:2291, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2288     self.state.epoch = epoch + (step + 1 + steps_skipped) / steps_in_epoch
#    2289     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 2291     self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2292 else:
#    2293     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File ~\anaconda3\envs\tf\lib\site-packages\transformers\trainer.py:2721, in Trainer._maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2719 metrics = None
#    2720 if self.control.should_evaluate:
# -> 2721     metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    2722     self._report_to_hp_search(trial, self.state.global_step, metrics)
#    2724     # Run delayed LR scheduler now that metrics are populated
#
# File ~\anaconda3\envs\tf\lib\site-packages\transformers\trainer.py:3572, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3569 start_time = time.time()
#    3571 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3572 output = eval_loop(
#    3573     eval_dataloader,
#    3574     description="Evaluation",
#    3575     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    3576     # self.args.prediction_loss_only
#    3577     prediction_loss_only=True if self.compute_metrics is None else None,
#    3578     ignore_keys=ignore_keys,
#    3579     metric_key_prefix=metric_key_prefix,
#    3580 )
#    3582 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    3583 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File ~\anaconda3\envs\tf\lib\site-packages\transformers\trainer.py:3747, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    3744 observed_num_examples = 0
#    3746 # Main evaluation loop
# -> 3747 for step, inputs in enumerate(dataloader):
#    3748     # Update the observed num examples
#    3749     observed_batch_size = find_batch_size(inputs)
#    3750     if observed_batch_size is not None:
#
# File ~\anaconda3\envs\tf\lib\site-packages\accelerate\data_loader.py:463, in DataLoaderShard.__iter__(self)
#     460 try:
#     461     # But we still move it to the device so it is done before `StopIteration` is reached
#     462     if self.device is not None:
# --> 463         current_batch = send_to_device(current_batch, self.device, non_blocking=self._non_blocking)
#     464     next_batch = next(dataloader_iter)
#     465     if batch_index >= self.skip_batches:
#
# File ~\anaconda3\envs\tf\lib\site-packages\accelerate\utils\operations.py:157, in send_to_device(tensor, device, non_blocking, skip_keys)
#     155     return tensor.to(device, non_blocking=non_blocking)
#     156 except TypeError:  # .to() doesn't accept non_blocking as kwarg
# --> 157     return tensor.to(device)
#     158 except AssertionError as error:
#     159     # `torch.Tensor.to(<int num>)` is not supported by `torch_npu` (see this [issue](https://github.com/Ascend/pytorch/issues/16)).
#     160     # This call is inside the try-block since is_npu_available is not supported by torch.compile.
#     161     if is_npu_available():
#
# File ~\anaconda3\envs\tf\lib\site-packages\transformers\tokenization_utils_base.py:800, in BatchEncoding.to(self, device)
#     796 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     797 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     798 # into a HalfTensor
#     799 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 800     self.data = {k: v.to(device=device) for k, v in self.data.items()}
#     801 else:
#     802     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# File ~\anaconda3\envs\tf\lib\site-packages\transformers\tokenization_utils_base.py:800, in <dictcomp>(.0)
#     796 # This check catches things like APEX blindly calling "to" on all inputs to a module
#     797 # Otherwise it passes the casts down and casts the LongTensor containing the token idxs
#     798 # into a HalfTensor
#     799 if isinstance(device, str) or is_torch_device(device) or isinstance(device, int):
# --> 800     self.data = {k: v.to(device=device) for k, v in self.data.items()}
#     801 else:
#     802     logger.warning(f"Attempting to cast a BatchEncoding to type {str(device)}. This is not supported.")
#
# KeyboardInterrupt:

# %%
now = datetime.now()
print(now.time())

# %%
# tokenizer = AutoTokenizer.from_pretrained("C:/Users/mosab/Desktop/Jupyter Notebook/Research/models/moussaKam-AraBART")
# model = AutoModelForSeq2SeqLM.from_pretrained("C:/Users/mosab/Desktop/Jupyter Notebook/Research/models/moussaKam-AraBART")

# # # Fine-tune the model
# # training_args = TrainingArguments(
# #     output_dir='./results',
# #     per_device_eval_batch_size=4,  # Batch size for CPU predictions
# #     dataloader_num_workers=7,  # Number of CPU workers to load the data
# #     fp16=False,  # Disable mixed precision for CPU predictions
# #     eval_accumulation_steps=8,  # Accumulate gradients to reduce memory usage
# #     no_cuda=True,  # Ensure it runs on CPU
# # )

# %%
# # Prepare test dataset
# max_length_input=190
# test_dataset = Dataset.from_pandas(test_df).map(preprocess_function_test, batched=True)

# # Move the model to CPU explicitly
# model.to(torch.device('cuda'))

# # import torch
# # torch.cuda.empty_cache()

# # import os
# # os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# # Generate answers
# outputs = model.generate(test_dataset, max_length=max_length_output)
# predictions_list = tokenizer.batch_decode(predictions, skip_special_tokens=True)

# %%
from tqdm import tqdm  # For progress tracking
from torch.utils.data import DataLoader


train_dataset = Dataset.from_pandas(train_df).map(preprocess_function_test, batched=True)

# Convert the Hugging Face Dataset to a DataLoader
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=False)  # Adjust batch size as needed

# Explicitly set dataset format to PyTorch tensors
train_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])

# Move the model to GPU
model.to(torch.device('cuda'))

# Generate predictions for each batch in the DataLoader with a progress bar
predictions_list = []
for batch in tqdm(train_loader, desc="Generating Predictions"):
    # Move the input tensors to the same device as the model
    input_ids = batch['input_ids'].to(torch.device('cuda'))
    attention_mask = batch['attention_mask'].to(torch.device('cuda'))

    # Generate predictions
    with torch.no_grad():
        outputs = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=max_length_output)
    predictions = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    predictions_list.extend(predictions)  # Collect predictions for all batches
# Out:
# Map:   0%|          | 0/178160 [00:00<?, ? examples/s]
# Generating Predictions: 100%|██████████| 22270/22270 [9:14:53<00:00,  1.50s/it]

# %%
# from tqdm import tqdm  # For progress tracking
# from torch.utils.data import DataLoader


# test_dataset = Dataset.from_pandas(test_df).map(preprocess_function_test, batched=True)

# # Convert the Hugging Face Dataset to a DataLoader
# test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False)  # Adjust batch size as needed

# # Explicitly set dataset format to PyTorch tensors
# test_dataset.set_format(type="torch", columns=["input_ids", "attention_mask"])

# # Move the model to GPU
# model.to(torch.device('cuda'))

# # Generate predictions for each batch in the DataLoader with a progress bar
# predictions_list = []
# for batch in tqdm(test_loader, desc="Generating Predictions"):
#     # Move the input tensors to the same device as the model
#     input_ids = batch['input_ids'].to(torch.device('cuda'))
#     attention_mask = batch['attention_mask'].to(torch.device('cuda'))

#     # Generate predictions
#     with torch.no_grad():
#         outputs = model.generate(input_ids=input_ids, attention_mask=attention_mask, max_length=max_length_output)
#     predictions = tokenizer.batch_decode(outputs, skip_special_tokens=True)
#     predictions_list.extend(predictions)  # Collect predictions for all batches

# %%
test_df.head()
# Out:
#                                                  question  \
# 98430   انا اشرب اقراص منع الحمل ميليان بسبب وجود كيس ...
# 63413   انا عملت تحليل سكر صائم وتراكمي وتحليل كوليستر...
# 78772   بنتي عمرها سنتين ونصف كيف احميها من امرض الشتا...
# 236651  هل كثر المجهود في الشهر السابع والثامن من الحم...
# 196301  هل نقص الكالسيوم في الجسم يسبب الديسك او له عل...
#
#                                                    answer  \
# 98430                                            نعم تؤثر
# 63413   نتيجه السكر التراكمي جدا ممتازه وتتدل علي عدم ...
# 78772   الحمايه تكون في المحافظه علي الطفل من اماكن ال...
# 236651                                       نعم يعمل ذلك
# 196301            ليس له علاقه بالدسك بل يسبب هشاشه العظم
#
#                                category
# 98430                      امراض نسائية
# 63413                        الطب العام
# 78772                     امراض الاطفال
# 236651                     امراض نسائية
# 196301  امراض العضلات والعظام و المفاصل

# %%
# # Prepare datasets for fine-tuning the AraBART model
# def preprocess_function_test(examples):
#     input_texts = []
#     for question, answer, category in zip(examples['question'], examples['answer'], examples['category']): #examples['predicted_category']
#         input_texts.append(f"category: {category} question: {question}")
#     #model_inputs = tokenizer(input_texts, max_length=max_length_input, truncation=True, padding="max_length")
#     #return model_inputs
#     return input_texts
# test_prepared=test_df.apply(lambda x: preprocess_function_test(x),axis=1)

# %%
# from torch.utils.data import Subset
# from tqdm import tqdm  # For progress tracking

# test_dataset = Dataset.from_pandas(test_df).map(preprocess_function_test, batched=True)

# # Split the test dataset into smaller subsets (e.g., chunks of 100)
# num_samples = len(test_dataset)
# chunk_size = 50  # Adjust based on memory availability
# predictions_list = []

# for i in tqdm(range(0, num_samples, chunk_size)):
#     subset = Subset(test_dataset, range(i, min(i + chunk_size, num_samples)))
    
    
#     predictions = trainer.predict(subset)
#     predictions_list.append(predictions)
    

# # If you want to decode the actual labels as well:
# decoded_preds=[]
# decoded_labels = []
# for pred in predictions_list:
#     decoded_preds.extend(tokenizer.batch_decode(pred.predictions, skip_special_tokens=True))
#     decoded_labels.extend(tokenizer.batch_decode(pred.label_ids, skip_special_tokens=True))

# # Display some predictions and labels for comparison
# for i in range(5):  # Show the first 5 examples
#     print(f"Prediction {i}: {decoded_preds[i]}")
#     print(f"Label {i}: {decoded_labels[i]}")

# %%
import pickle

# Save predictions_list to a file
with open("models/train_predictions_list-moussaKam-AraBART.pkl", "wb") as file:
    pickle.dump(predictions_list, file)

# %%
# import pickle

# # Save predictions_list to a file
# with open("models/predictions_list-moussaKam-AraBART.pkl", "wb") as file:
#     pickle.dump(predictions_list, file)

# %%
# # Load predictions_list from a file
# with open("models/predictions_list-moussaKam-AraBART.pkl", "rb") as file:
#     predictions_list = pickle.load(file)

# %%
# import numpy as np
# from nltk.translate.bleu_score import sentence_bleu
# # Test and calculate BLEU score
# chencherry = SmoothingFunction()

# def compute_bleu_score(preds, labels):
#     bleu_scores = []
#     for pred, label in zip(preds, labels):
#         reference = [label.split()]
#         candidate = pred.split()
#         bleu_scores.append(sentence_bleu(reference, candidate, smoothing_function=chencherry.method1))
#     return np.mean(bleu_scores)

# # Compute BLEU score
# bleu_score = compute_bleu_score(predictions_list, test_df['answer'])
# print(f"BLEU Score: {bleu_score}")

# %%
# from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# reference = [["this", "is", "a", "reference", "sentence"]]  # List of lists
# candidate = ["this", "is", "a", "predicted", "sentence"]   # Single list

# score = sentence_bleu(reference, candidate)
# print("BLEU score:", score)

# %%
# from nltk.translate.bleu_score import sentence_bleu

# reference = [["this", "is", "a", "reference", "sentence"]]  # List of lists
# candidate = ["this", "is", "a", "reference", "sentence"]   # Single list

# score = sentence_bleu(reference, candidate)
# print("BLEU score:", score)

# %%
list(train_df['question'][0:5])
# Out:
# ['هل اشعه الراوتر الذي يستخدم في بث الانترنت مضر لاني استعمله كثيرا في البيت ويبقي مفتوح دائما حتي وقت النوم وبالنسبه للهاتف اشعه ايضا مضره ارجو الاجابه رجا',
#  'اسباب الحرقه البسيطه عند التبول عند الرجال',
#  'السلام عليكم طهور فطريات في اللثه واختفت خلال يوم وبدات شفتي تحمر وتقشر من فتره سته شهور هل هذه يدل علي اصابه بالايدز الرجاء الرد شكرا',
#  'ظهرت لدي حبوب وتقرحات تحرق الجلد في منطقه البطن ولا اعرف سببها علما باني صحيت من النوم علي حكه في تلك المنطقه واشعر احيانا بشي يتحرك تحت المنطقه المصلابه',
#  'انا فتاه في الثامنه عشر من العمر لدي الم في اسفل البطن وفي الدوره الشهريه ينزل دم متخثر او علي شكل خيوط لزجه ماسبب ذلك وماهي هذه الاعراض']

# %%
predictions_list[0:5]
# Out:
# ['لا ضرر من ذلك',
#  'الحرقه البسيطه عند الرجال قد تكون نتيجه البروتينات في المسالك البوليه او وجود حصوه في التحليلين',
#  'لا علاقه للفطريات بالايدز راجع اختصاصي امرض جلديه',
#  'استخدم كريم يحتوي البويضه 5 ايام ومضاد حيوي',
#  'افحص سونار']

# %%
list(train_df['answer'][0:5])
# Out:
# ['لا يوجد الي الان اي دليل علمي يفيد بان الاشعه التي تنبثق من اجهزه الراوتر مضره كون نسبه الاشعاع سكانارللظهروحكوا ضئيله جدا لتسبب اي ضرر',
#  'البروتينات استخداماته',
#  'هذه اعراض عامه راجع اختصاصي امرض الاسنان اولا',
#  'يجب اخذ السيره المرضيه وفحص المنطقه لامكانيه التشخيص',
#  'افحص سونار']

# %%
from collections import Counter
import math

def calculate_bleu(predictions, references, max_n=4, weights=[0.25, 0.25, 0.25, 0.25]):
    total_candidate_length = 0
    total_reference_length = 0
    ngram_precisions = []

    # Step 1: Compute n-gram precisions for each n (1 to max_n)
    for n in range(1, max_n + 1):
        ngram_matches = 0
        ngram_total = 0
        
        for prediction, reference in zip(predictions, references):
            # Convert sentences to tokens
            pred_tokens = prediction.split()
            ref_tokens = reference.split()
            
            # Update lengths for brevity penalty calculation
            total_candidate_length += len(pred_tokens)
            total_reference_length += len(ref_tokens)
            
            # Generate n-grams for prediction and reference
            pred_ngrams = [tuple(pred_tokens[i:i+n]) for i in range(len(pred_tokens)-n+1)]
            ref_ngrams = [tuple(ref_tokens[i:i+n]) for i in range(len(ref_tokens)-n+1)]
            
            # Count n-gram matches
            pred_ngram_counts = Counter(pred_ngrams)
            ref_ngram_counts = Counter(ref_ngrams)
            
            # Calculate clipped counts
            for ngram in pred_ngram_counts:
                ngram_matches += min(pred_ngram_counts[ngram], ref_ngram_counts[ngram])
            ngram_total += len(pred_ngrams)
        
        # Precision for current n-gram level
        precision = (ngram_matches / ngram_total) if ngram_total > 0 else 0
        ngram_precisions.append(precision)

    # Step 2: Calculate log-precision sum with weights
    weighted_log_precisions = sum(weights[i] * math.log(ngram_precisions[i]) for i in range(max_n) if ngram_precisions[i] > 0)
    
    # Step 3: Calculate Brevity Penalty (BP)
    if total_candidate_length > total_reference_length:
        BP = 1
    else:
        BP = math.exp(1 - (total_reference_length / total_candidate_length)) if total_candidate_length > 0 else 0

    # Step 4: Compute BLEU score
    bleu_score = BP * math.exp(weighted_log_precisions)

    return bleu_score

# Example usage
pred_list = ["the cat is on the mat", "there is a cat"]
ref_list = ["the cat is on the mat", "there is the cat"]

bleu_score = calculate_bleu(pred_list, ref_list)
print("BLEU Score:", bleu_score)
# Out:
# BLEU Score: 0.7621991222319221

# %%
bleu_score = calculate_bleu(predictions_list, train_df['answer'])

# %%
bleu_score
# Out:
# 0.02008533223539645

# %%
x=test_df['question'].apply(lambda x: len(x))

# %%
x.max()
# Out:
# 189

# %%
x.min()
# Out:
# 9

# %%
x.idxmin()
# Out:
# 160348

# %%
test_df['question'][160348]
# Out:
# 'علاج زكام'

# %%
x.mean()
# Out:
# 92.6962457337884

# %%
x=test_df['answer'].apply(lambda x: len(x))

# %%
x.max()
# Out:
# 229

# %%
x.min()
# Out:
# 6

# %%
x=test_df['category'].apply(lambda x: len(x))

# %%
x.max()
# Out:
# 32

# %%
x.min()
# Out:
# 10

# %%
test_df.shape
# Out:
# (25198, 3)

# %%
test_df.shape[0]/4
# Out:
# 6299.5

# %%
test_dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 test_dataset
#
# NameError: name 'test_dataset' is not defined

# %%
import sys

size_in_bytes = sys.getsizeof(test_dataset)
print(size_in_bytes)

# %%
type(test_dataset)

# %%
test_dataset[0]
